# %%
#import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
#from api_keys import api_key

# %%
import requests

url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"state""houston, tx"}

headers = {
	"X-RapidAPI-Key": "feef5045e0mshf94361e5475e633p161a6ejsn2ddb21b4ef68",
	"X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'abbreviatedAddress': '139 E Del Rio Dr',
#  'address': {'city': 'Tempe',
#              'community': None,
#              'neighborhood': None,
#              'state': 'AZ',
#              'streetAddress': '139 E Del Rio Dr',
#              'subdivision': None,
#              'zipcode': '85282'},
#  'apartmentsForRentInZipcodeSearchUrl': {'path': '/tempe-az-85282/apartments/'},
#  'attributionInfo': {'agentEmail': 'chris.tiller@russlyon.com',
#                      'agentLicenseNumber': None,
#                      'agentName': 'Christopher S. Tiller',
#                      'agentPhoneNumber': '480-750-7424',
#                      'attributionTitle': None,
#                      'brokerName': "Russ Lyon Sotheby's International Realty",
#                      'brokerPhoneNumber': '480-750-7424',
#                      'buyerAgentMemberStateLicense': 'SA680998000',
#                      'buyerAgentName': 'Amelia Goudeau',
# ...

# %%
city_data = pd.json_normalize(response["content"]["cities"])
city_data = city_data.sort_values(["price"],ascending=False)
city_data["price"]=city_data["price"]
city_data = city_data.reset_index(drop= True)
city_data = city_data.drop(["yearBuilt"],axis=1)
city_data_cleaned=city_data.rename(columns={'city':"City","state":"State", "price":"zestimate","total_listing":"Total Airbnb Listing"})
city_data_cleaned
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1372\2367215329.py in <module>
# ----> 1 city_data = pd.json_normalize(response["city"])
#
# TypeError: 'Response' object is not subscriptable
